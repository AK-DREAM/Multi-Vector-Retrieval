# %%
import pickle
import torch
import torch.nn.functional as F
import os
os.environ["CUDA_VISIBLE_DEVICES"]="7"


device = torch.device("cuda")

# %%
from tqdm import tqdm
from torch.utils.data import DataLoader, TensorDataset

# %%
def cos_sim(a: torch.Tensor, b: torch.Tensor):
    """
    Computes the cosine similarity cos_sim(a[i], b[j]) for all i and j.
    :return: Matrix with res[i][j]  = cos_sim(a[i], b[j])
    """
    if not isinstance(a, torch.Tensor):
        a = torch.tensor(a)

    if not isinstance(b, torch.Tensor):
        b = torch.tensor(b)

    if len(a.shape) == 1:
        a = a.unsqueeze(0)

    if len(b.shape) == 1:
        b = b.unsqueeze(0)

    a_norm = torch.nn.functional.normalize(a, p=2, dim=1)
    b_norm = torch.nn.functional.normalize(b, p=2, dim=1)
    return torch.mm(a_norm, b_norm.transpose(0, 1))


with open("/home/icml01/multi_rag/RAG/Search-in-the-Chain/data/subcor.pkl", "rb") as file:
    all_sub_corpus_embedding_ls = pickle.load(file)


with open("query.pkl", "rb") as file:
    query_embeddings = pickle.load(file)
query_embeddings = [row[-2:] for row in query_embeddings]
query_count = len(query_embeddings)
# Out:
# /home/icml01/anaconda3/envs/rag/lib/python3.10/site-packages/torch/storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))

# %%
max_len = max(len(tensor) for row in query_embeddings for tensor in row) + 1
processed_tensors = []
for row in query_embeddings:
    concatenated_tensor = torch.cat(row, dim=0)
    padding_size = max_len - concatenated_tensor.size(0)  # 计算需要填充的长度
    # pad 参数: (left, right) -> (前向填充, 后向填充)，我们在第一维填充
    padded_tensor = F.pad(concatenated_tensor, (0, 0, padding_size, 0))  # 填充到 maxlen
    processed_tensors.append(
        padded_tensor
    )  # Stack to create a tensor of shape (maxlen, 768)
final_tensor = torch.stack(processed_tensors).to(device)  # Shape: [85, maxlen, 768]
final_tensor.shape
# Out:
# torch.Size([7405, 246, 768])

# %%
max(row.shape[0] for row in all_sub_corpus_embedding_ls for tensor in row)
# Out:
# 1

# %%
# 将所有 sub_corpus_embeddings 放到一个大 tensor 中，减少内存传输
all_sub_corpus_embeddings_tensor = torch.stack(all_sub_corpus_embedding_ls).to(device)  # [5233329, 2, 768]

# 批处理大小
batch_size = 64  # 根据你的 GPU 内存调整批次大小
num_batches = len(all_sub_corpus_embedding_ls) // batch_size + 1

all_cos_scores = []

dataset = TensorDataset(all_sub_corpus_embeddings_tensor)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)

# for batch_idx, (sub_corpus_embeddings_batch,) in enumerate(tqdm(dataloader)):
#     cos_scores_batch = raw_score_text(final_tensor, sub_corpus_embeddings_batch, device)
#     all_cos_scores.append(cos_scores_batch.cpu())  # 将结果从 GPU 移动到 CPU，防止内存溢出

# %%
dataloader_iter = iter(dataloader)
first_batch = next(dataloader_iter)[0]
first_batch
# Out:
# tensor([[[ 0.0037,  0.0124, -0.0096,  ..., -0.0142, -0.0061,  0.0484]],
#
#         [[-0.0007,  0.0007, -0.0181,  ..., -0.0014, -0.0194, -0.0014]],
#
#         [[-0.0012, -0.0089,  0.0156,  ...,  0.0110, -0.0032,  0.0421]],
#
#         ...,
#
#         [[ 0.0130,  0.0052, -0.0245,  ..., -0.0145,  0.0140,  0.0474]],
#
#         [[-0.0036,  0.0019, -0.0134,  ..., -0.0222, -0.0134,  0.0174]],
#
#         [[ 0.0056,  0.0049, -0.0345,  ...,  0.0084, -0.0209,  0.0270]]],
#        device='cuda:0')

# %%
sub_corpus_embeddings = all_sub_corpus_embedding_ls[0]

# %%
final_tensor = final_tensor.to(device)
sub_corpus_embeddings = sub_corpus_embeddings.to(device)

batch_size, num_queries, embedding_dim = final_tensor.shape
sub_corpus_embeddings_norm = torch.nn.functional.normalize(
    sub_corpus_embeddings, p=2, dim=1
)
final_tensor_norm = torch.nn.functional.normalize(final_tensor, p=2, dim=-1)

print(final_tensor_norm.shape, sub_corpus_embeddings_norm.shape)

cos_sim_matrix = torch.matmul(final_tensor_norm, sub_corpus_embeddings_norm.T)

print(cos_sim_matrix.shape)

# max_cos_sim, _ = torch.max(cos_sim_matrix, dim=-1)

# print(max_cos_sim.shape)

last_query_embeddings = final_tensor[:, -1, :]
last_query_cos_sim2 = torch.matmul(last_query_embeddings, sub_corpus_embeddings.T)  # [:, 0]

print(last_query_cos_sim.shape)

curr_scores_ls = cos_sim_matrix[:, :-1]

curr_scores_ls[curr_scores_ls == 0] = 1
curr_scores_ls[curr_scores_ls < 0] = 0

prod_scores2 = torch.prod(curr_scores_ls, dim=1)

print(prod_scores.shape)
# Out:
# torch.Size([7405, 246, 768]) torch.Size([1, 768])
# torch.Size([7405, 246, 1])
# torch.Size([7405, 64])
# torch.Size([7405, 64])

# %%
combined_column_tensor = torch.stack((prod_scores, last_query_cos_sim), dim=-1)  # shape: [7405, 64, 2]

combined_tensor = combined_column_tensor.permute(1, 0, 2)  # shape: [64, 7405, 2]

combined_tensor.shape
# Out:
# torch.Size([64, 7405, 2])

# %%
import torch

from tqdm import tqdm


def raw_score_text(final_tensor, sub_corpus_embeddings, device):
    final_tensor = final_tensor.to(device)
    sub_corpus_embeddings = sub_corpus_embeddings.reshape(64, 768).to(device)

    sub_corpus_embeddings_norm = torch.nn.functional.normalize(
        sub_corpus_embeddings, p=2, dim=1
    )
    final_tensor_norm = torch.nn.functional.normalize(final_tensor, p=2, dim=-1)
    # print(final_tensor_norm.shape, sub_corpus_embeddings_norm.shape)
  
    cos_sim_matrix = torch.matmul(final_tensor_norm, sub_corpus_embeddings_norm.T)

    last_query_embeddings = final_tensor[:, -1, :]
    last_query_cos_sim = torch.matmul(last_query_embeddings, sub_corpus_embeddings_norm.T)  # [:, 0]

    curr_scores_ls = cos_sim_matrix[:, :-1]

    curr_scores_ls[curr_scores_ls == 0] = 1
    curr_scores_ls[curr_scores_ls < 0] = 0

    prod_scores = torch.prod(curr_scores_ls, dim=1)
    combined_column_tensor = torch.stack((prod_scores, last_query_cos_sim), dim=-1)  # shape: [7405, 64, 2]

    combined_tensor = combined_column_tensor.permute(1, 0, 2)  # shape: [64, 7405, 2]
    

    return combined_tensor


def process_all_embeddings(final_tensor, all_sub_corpus_embedding_ls, device):
    # 将所有 sub_corpus_embeddings 放到一个大 tensor 中，减少内存传输
    all_sub_corpus_embeddings_tensor = torch.stack(all_sub_corpus_embedding_ls).to(
        device
    )  # [5233329, 2, 768]

    # 批处理大小
    batch_size = 64  # 根据你的 GPU 内存调整批次大小
    num_batches = len(all_sub_corpus_embedding_ls) // batch_size + 1

    all_cos_scores = []

    # 使用 DataLoader 进行批量处理
    dataset = TensorDataset(all_sub_corpus_embeddings_tensor)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)

    for batch_idx, (sub_corpus_embeddings_batch,) in enumerate(tqdm(dataloader)):
        cos_scores_batch = raw_score_text(
            final_tensor, sub_corpus_embeddings_batch, device
        )
        # print(cos_scores_batch.shape)
        all_cos_scores.append(cos_scores_batch)  # 将结果从 GPU 移动到 CPU，防止内存溢出

    return torch.cat(all_cos_scores, dim=0)


all_cos_scores = process_all_embeddings(
    final_tensor, all_sub_corpus_embedding_ls, device
)
# Out:
# 100%|██████████| 4/4 [00:00<00:00, 556.18it/s]

# %%
all_cos_scores.shape
# Out:
# torch.Size([256, 7405, 2])

# %% [markdown]
# ## 准确性测试

# %%
all_cos_scores = []

for sub_corpus_embeddings in tqdm(all_sub_corpus_embedding_ls):
    cos_scores = []
    for query_itr in range(query_count):
        curr_query_embedding_ls = query_embeddings[query_itr]
        if type(curr_query_embedding_ls) is list:  # [3,768][1,768]
            full_curr_scores_ls = []

            for sub_q_ls_idx in range(len(curr_query_embedding_ls)):
                curr_query_embedding = curr_query_embedding_ls[sub_q_ls_idx]
                curr_scores = 1

                if curr_query_embedding.shape[0] == 1:
                    curr_scores_ls = torch.max(
                        cos_sim(
                            curr_query_embedding.to(device),
                            sub_corpus_embeddings.to(device),
                        ),
                        dim=-1,
                    )[0]
                    curr_scores = curr_scores_ls
                    full_curr_scores_ls.append(curr_scores.item())
                    continue

                curr_scores_ls = cos_sim(
                    curr_query_embedding.to(device), sub_corpus_embeddings.to(device)
                )  # , dim=-1)

                curr_scores = torch.max(torch.prod(curr_scores_ls, dim=0))
                full_curr_scores_ls.append(curr_scores.item())

            curr_scores = torch.tensor(full_curr_scores_ls)

        cos_scores.append(curr_scores)

    cos_scores = torch.stack(cos_scores)
    all_cos_scores.append(cos_scores)
all_cos_scores_tensor = torch.stack(all_cos_scores, dim=-1)
# Out:
# 100%|██████████| 256/256 [09:12<00:00,  2.16s/it]

# %%
all_cos_scores_tensor
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 all_cos_scores_tensor
#
# NameError: name 'all_cos_scores_tensor' is not defined

# %%
def raw_score_fnc_batch(final_tensor, sub_corpus_embeddings, device):
    final_tensor = final_tensor.to(device) 
    sub_corpus_embeddings = sub_corpus_embeddings.to(device) 
   
    sub_corpus_embeddings_norm = torch.nn.functional.normalize(sub_corpus_embeddings, p=2, dim=1).to(device)
    final_tensor_norm = torch.nn.functional.normalize(final_tensor, p=2, dim=-1).to(device)

    cos_sim_matrix = torch.matmul(final_tensor_norm, sub_corpus_embeddings_norm.T)

    max_cos_sim, _ = torch.max(cos_sim_matrix, dim=-1) 

    last_query_embeddings = final_tensor[:, -1, :].to(device)  # Shape: [batch_size, embedding_dim]
    # last_corpus_embedding = sub_corpus_embeddings[-1].to(device).unsqueeze(0)
    last_query_cos_sim = torch.matmul(last_query_embeddings, sub_corpus_embeddings_norm.T)

    curr_scores_ls = max_cos_sim[:, :-1]  # Exclude the last query from max similarity scores
    curr_scores_ls[curr_scores_ls == 0] = 1
    curr_scores_ls[curr_scores_ls < 0] = 0

    # Compute product for each batch
    prod_scores = torch.prod(curr_scores_ls, dim=1)

    # Concatenate product scores with last query similarity
    final_scores = torch.cat([prod_scores.unsqueeze(1), last_query_cos_sim], dim=1)  # Shape: [batch_size, 2]

    del sub_corpus_embeddings_norm, final_tensor_norm, cos_sim_matrix
    del last_query_embeddings, curr_scores_ls, prod_scores

    return final_scores

# %%
all_cos_scores = []

for sub_corpus_embeddings in tqdm(all_sub_corpus_embedding_ls):
    raw_score_fnc_batch(final_tensor, sub_corpus_embeddings, device)
    all_cos_scores.append(cos_scores)
all_cos_scores_tensor2 = torch.stack(all_cos_scores, dim=-1)
# Out:
#   0%|          | 0/256 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[48], line 4
#       1 all_cos_scores = []
#       3 for sub_corpus_embeddings in tqdm(all_sub_corpus_embedding_ls):
# ----> 4     raw_score_fnc_batch(final_tensor, sub_corpus_embeddings, device)
#       5     all_cos_scores.append(cos_scores)
#       6 all_cos_scores_tensor2 = torch.stack(all_cos_scores, dim=-1)
#
# Cell In[47], line 58, in raw_score_fnc_batch(final_tensor, sub_corpus_embeddings, device)
#      55 cos_sim_matrix = torch.matmul(final_tensor_norm, sub_corpus_embeddings_norm.T)
#      57 # Compute max cosine similarity for each query across corpus embeddings
# ---> 58 max_cos_sim, _ = torch.max(cos_sim_matrix, dim=-1)  # Shape: [batch_size, num_queries]
#      60 # Handle the special case for the last embedding
#      61 last_query_embeddings = final_tensor[:, -1, :].to(device)  # Shape: [batch_size, embedding_dim]
#
# IndexError: max(): Expected reduction dim 2 to have non-zero size.

# %%
all_cos_scores_tensor2
# Out:
# tensor([[[0.3493, 0.3493, 0.3493,  ..., 0.3493, 0.3493, 0.3493],
#          [0.7284, 0.7284, 0.7284,  ..., 0.7284, 0.7284, 0.7284]],
#
#         [[0.6829, 0.6829, 0.6829,  ..., 0.6829, 0.6829, 0.6829],
#          [0.7197, 0.7197, 0.7197,  ..., 0.7197, 0.7197, 0.7197]],
#
#         [[0.0366, 0.0366, 0.0366,  ..., 0.0366, 0.0366, 0.0366],
#          [0.7078, 0.7078, 0.7078,  ..., 0.7078, 0.7078, 0.7078]],
#
#         ...,
#
#         [[0.6837, 0.6837, 0.6837,  ..., 0.6837, 0.6837, 0.6837],
#          [0.6819, 0.6819, 0.6819,  ..., 0.6819, 0.6819, 0.6819]],
#
#         [[0.6888, 0.6888, 0.6888,  ..., 0.6888, 0.6888, 0.6888],
#          [0.7156, 0.7156, 0.7156,  ..., 0.7156, 0.7156, 0.7156]],
#
#         [[0.7623, 0.7623, 0.7623,  ..., 0.7623, 0.7623, 0.7623],
#          [0.7638, 0.7638, 0.7638,  ..., 0.7638, 0.7638, 0.7638]]])

# %%
def raw_score_text(final_tensor, sub_corpus_embeddings, device):
    final_tensor = final_tensor.to(device)
    sub_corpus_embeddings = sub_corpus_embeddings.reshape(sub_corpus_embeddings.shape[0], sub_corpus_embeddings.shape[-1]).to(device)

    sub_corpus_embeddings_norm = torch.nn.functional.normalize(
        sub_corpus_embeddings, p=2, dim=1
    )
    final_tensor_norm = torch.nn.functional.normalize(final_tensor, p=2, dim=-1)
    # print(final_tensor_norm.shape, sub_corpus_embeddings_norm.shape)
  
    cos_sim_matrix = torch.matmul(final_tensor_norm, sub_corpus_embeddings_norm.T)
    # cos_sim_matrix = 1 - torch.cdist(final_tensor_norm, sub_corpus_embeddings_norm, p=2)

    last_query_embeddings = final_tensor[:, -1, :]
    last_query_cos_sim = torch.matmul(last_query_embeddings, sub_corpus_embeddings_norm.T)  # [:, 0]

    curr_scores_ls = cos_sim_matrix[:, :-1]

    curr_scores_ls[curr_scores_ls == 0] = 1
    curr_scores_ls[curr_scores_ls < 0] = 0

    prod_scores = torch.prod(curr_scores_ls, dim=1)
    #     combined_column_tensor = torch.stack((prod_scores, last_query_cos_sim), dim=-1)  # shape: [7405, 64, 2]

    #     combined_tensor = combined_column_tensor.permute(1, 0, 2)  # shape: [64, 7405, 2]
    combined_column_tensor = torch.stack((prod_scores, last_query_cos_sim), dim=1)
    
    return combined_column_tensor


def process_all_embeddings(final_tensor, all_sub_corpus_embedding_ls, device):
    # 将所有 sub_corpus_embeddings 放到一个大 tensor 中，减少内存传输
    all_sub_corpus_embeddings_tensor = torch.stack(all_sub_corpus_embedding_ls).to(
        device
    )  # [5233329, 2, 768]

    # 批处理大小
    batch_size = 64  # 根据你的 GPU 内存调整批次大小
    num_batches = len(all_sub_corpus_embedding_ls) // batch_size + 1

    all_cos_scores = []

    # 使用 DataLoader 进行批量处理
    dataset = TensorDataset(all_sub_corpus_embeddings_tensor)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)

    for batch_idx, (sub_corpus_embeddings_batch,) in enumerate(tqdm(dataloader)):
        cos_scores_batch = raw_score_text(
            final_tensor, sub_corpus_embeddings_batch, device
        )
        # print(cos_scores_batch.shape)
        all_cos_scores.append(cos_scores_batch)  # 将结果从 GPU 移动到 CPU，防止内存溢出

    return torch.cat(all_cos_scores, dim=-1)

# %%
max_len = max(len(tensor) for row in query_embeddings for tensor in row) + 1
processed_tensors = []
for row in query_embeddings:
    concatenated_tensor = torch.cat(row, dim=0)
    padding_size = max_len - concatenated_tensor.size(0)  # 计算需要填充的长度
    # pad 参数: (left, right) -> (前向填充, 后向填充)，我们在第一维填充
    padded_tensor = F.pad(concatenated_tensor, (0, 0, padding_size, 0))  # 填充到 maxlen
    processed_tensors.append(padded_tensor)  # Stack to create a tensor of shape (maxlen, 768)
final_tensor = torch.stack(processed_tensors).to(device)  # Shape: [85, maxlen, 768]


all_cos_scores_tensor3 = process_all_embeddings(
    final_tensor, all_sub_corpus_embedding_ls, device
)
# Out:
# 100%|██████████| 4/4 [00:00<00:00, 1112.40it/s]

# %%
torch.allclose(all_cos_scores_tensor2.to(device), all_cos_scores_tensor.to(device), atol=1e-4)
# Out:
# True

#          6.8321e-01, 7.2904e-01, 7.1332e-01, 7.1412e-01, 7.4794e-01, 7.1109e-01,
#          7.3290e-01, 6.8173e-01, 7.1010e-01, 6.6304e-01, 7.1119e-01, 7.1153e-01,
#          7.4098e-01, 6.8658e-01, 6.7885e-01, 7.0175e-01, 6.7062e-01, 6.7965e-01,
#          7.1253e-01, 7.0708e-01, 6.8620e-01, 6.8590e-01, 7.1457e-01, 7.1498e-01,
#          7.2142e-01, 7.2332e-01, 7.0733e-01, 7.1480e-01, 7.2690e-01, 6.9098e-01,
#          7.4708e-01, 7.3354e-01, 7.3099e-01, 7.3198e-01, 7.3494e-01, 7.2549e-01,
#          7.3059e-01, 7.2028e-01, 6.8181e-01, 7.1667e-01, 7.0339e-01, 7.2563e-01,
#          7.2707e-01, 7.3527e-01, 7.5000e-01, 7.1149e-01, 7.2702e-01, 7.1384e-01,
#          6.9942e-01, 6.9686e-01, 7.1340e-01, 7.2507e-01, 7.1158e-01, 7.0196e-01,
#          7.5156e-01, 7.5297e-01, 6.7934e-01, 6.9284e-01, 7.2172e-01, 7.0167e-01,
#          7.3079e-01, 6.9390e-01, 7.4085e-01, 6.8631e-01, 7.1910e-01, 6.9944e-01,
#          7.1172e-01, 7.1198e-01, 7.2155e-01, 7.1309e-01, 7.1672e-01, 7.2130e-01,
#          7.4899e-01, 7.1988e-01, 7.1684e-01, 7.5344e-01, 7.2192e-01, 7.0487e-01,
#          6.9468e-01, 7.3691e-01, 6.9858e-01, 7.0321e-01]], device='cuda:0')

# %%
cos_scores = []
sub_corpus_embeddings = all_sub_corpus_embedding_ls[0]
for query_itr in range(query_count):
    curr_query_embedding_ls = query_embeddings[query_itr]
    if type(curr_query_embedding_ls) is list:  # [3,768][1,768]
        full_curr_scores_ls = []

        for sub_q_ls_idx in range(len(curr_query_embedding_ls)):
            curr_query_embedding = curr_query_embedding_ls[sub_q_ls_idx]
            curr_scores = 1

            if curr_query_embedding.shape[0] == 1:
                curr_scores_ls = torch.max(
                    cos_sim(
                        curr_query_embedding.to(device),
                        sub_corpus_embeddings.to(device),
                    ),
                    dim=-1,
                )[0]
                curr_scores = curr_scores_ls
                full_curr_scores_ls.append(curr_scores.item())
                continue

            curr_scores_ls = cos_sim(
                curr_query_embedding.to(device), sub_corpus_embeddings.to(device)
            )  # , dim=-1)

            curr_scores = torch.max(torch.prod(curr_scores_ls, dim=0))
            full_curr_scores_ls.append(curr_scores.item())

        curr_scores = torch.tensor(full_curr_scores_ls)

    cos_scores.append(curr_scores)

cos_scores = torch.stack(cos_scores)

# %%
cos_scores
# Out:
# tensor([[0.2829, 0.6970],
#         [0.6639, 0.7010],
#         [0.0336, 0.6900],
#         ...,
#         [0.6611, 0.6751],
#         [0.6724, 0.6932],
#         [0.6914, 0.6980]])

# %%
def raw_score_text(final_tensor, sub_corpus_embeddings, device):
    final_tensor = final_tensor.to(device)
    sub_corpus_embeddings = sub_corpus_embeddings.to(
        device
    )  # Move sub_corpus_embeddings to device

    batch_size, num_queries, embedding_dim = final_tensor.shape

    sub_corpus_embeddings_tensor = sub_corpus_embeddings # [:-1]

    sub_corpus_embeddings_norm = torch.nn.functional.normalize(
        sub_corpus_embeddings_tensor, p=2, dim=1
    ).to(device)

    final_tensor_norm = torch.nn.functional.normalize(final_tensor, p=2, dim=-1).to(
        device
    )

    cos_sim_matrix = torch.matmul(final_tensor_norm, sub_corpus_embeddings_norm.T)

    # Compute max cosine similarity for each query across corpus embeddings
    max_cos_sim, _ = torch.max(cos_sim_matrix, dim=-1)  # Shape: [batch_size, num_queries]

    # Handle the special case for the last embedding
    last_query_embeddings = final_tensor[:, -1, :].to(device)  # Shape: [batch_size, embedding_dim]
    last_query_cos_sim = cos_sim(last_query_embeddings, sub_corpus_embeddings)[:, 0]  # Shape: [batch_size]

    # Combine scores
    curr_scores_ls = max_cos_sim[:, :-1]  # Exclude the last query from max similarity scores
    curr_scores_ls[curr_scores_ls == 0] = 1
    curr_scores_ls[curr_scores_ls < 0] = 0

    # Compute product for each batch
    prod_scores = torch.prod(curr_scores_ls, dim=1) 

    # Concatenate product scores with last query similarity
    final_scores = torch.cat([prod_scores.unsqueeze(1), last_query_cos_sim.unsqueeze(1)], dim=1)  # Shape:
    
    return final_scores


cos_scores = raw_score_text(final_tensor, sub_corpus_embeddings, device)
cos_scores
# Out:
# tensor([[0.2829, 0.6970],
#         [0.6639, 0.7010],
#         [0.0336, 0.6900],
#         ...,
#         [0.6611, 0.6751],
#         [0.6724, 0.6932],
#         [0.6914, 0.6980]], device='cuda:0')

# %% [markdown]
# # qrel

# %%
from beir.datasets.data_loader import GenericDataLoader
# Out:
# /home/icml01/multi_rag/RAG/Decompose_retrieval/beir/datasets/data_loader.py:2: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
data_path = "/home/icml01/multi_rag/RAG/Search-in-the-Chain/data/hotpotqa/hotpotqa"

corpus, queries, qrels = GenericDataLoader(
    data_folder=data_path).load(split="test"
)
# Out:
#   0%|          | 0/5233329 [00:00<?, ?it/s]
# IOStream.flush timed out

# %%
corpus['12']
# Out:
# {'text': 'Anarchism is a political philosophy that advocates self-governed societies based on voluntary institutions. These are often described as stateless societies, although several authors have defined them more specifically as institutions based on non-hierarchical free associations. Anarchism holds the state to be undesirable, unnecessary and harmful.',
#  'title': 'Anarchism'}

# %%
queries
# Out:
# {'5a8b57f25542995d1e6f1371': 'Were Scott Derrickson and Ed Wood of the same nationality?',
#  '5a8c7595554299585d9e36b6': 'What government position was held by the woman who portrayed Corliss Archer in the film Kiss and Tell?',
#  '5a85ea095542994775f606a8': 'What science fantasy young adult series, told in first person, has a set of companion books narrating the stories of enslaved worlds and alien species?',
#  '5adbf0a255429947ff17385a': 'Are the Laleli Mosque and Esma Sultan Mansion located in the same neighborhood?',
#  '5a8e3ea95542995a26add48d': 'The director of the romantic comedy "Big Stone Gap" is based in what New York city?',
#  '5abd94525542992ac4f382d2': '2014 S/S is the debut album of a South Korean boy group that was formed by who?',
#  '5a85b2d95542997b5ce40028': 'Who was known by his stage name Aladin and helped organizations improve their performance as a consultant?',
#  '5a87ab905542996e4f3088c1': 'The arena where the Lewiston Maineiacs played their home games can seat how many people?',
#  '5a7bbb64554299042af8f7cc': 'Who is older, Annie Morton or Terry Richardson?',
#  '5a8db19d5542994ba4e3dd00': 'Are Local H and For Against both from the United States?',
#  '5a7166395542994082a3e814': 'What is the name of the fight song of the university whose main campus is in Lawrence, Kansas and whose branch campuses are in the Kansas City metropolitan area?',
#  '5a877e5d5542993e715abf7d': 'What screenwriter with credits for "Evolution" co-wrote a film starring Nicolas Cage and Téa Leoni?',
#  '5ab3b0bf5542992ade7c6e39': 'What year did Guns N Roses perform a promo for a movie starring Arnold Schwarzenegger as a former New York Police detective?',
#  '5ab56e32554299637185c594': 'Are Random House Tower and 888 7th Avenue both used for real estate?',
#  '5ab6d09255429954757d337d': 'The football manager who recruited David Beckham managed Manchester United during what timeframe?',
#  '5a75e05c55429976ec32bc5f': 'Brown State Fishing Lake is in a country that has a population of how many inhabitants ?',
#  '5ab3e45655429976abd1bcd4': "The Vermont Catamounts men's soccer team currently competes in a conference that was formerly known as what from 1988 to 1996?",
#  '5ab29c24554299449642c932': 'Are Giuseppe Verdi and Ambroise Thomas both Opera composers ?',
#  '5ae0d4c9554299603e418468': 'Roger O. Egeberg was Assistant Secretary for Health and Scientific Affairs during the administration of a president that served during what years?',
#  '5a8133725542995ce29dcbdb': 'Which writer was from England, Henry Roth or Robert Erskine Childers?',
#  '5ae7a8175542993210983ed8': 'Which other Mexican Formula One race car driver has held the podium besides the Force India driver born in 1990?',
#  '5ae6050f55429929b0807a5e': 'This singer of A Rather Blustery Day also voiced what hedgehog?',
#  '5adddccd5542997dc7907069': 'Aside from the Apple Remote, what other device can control the program Apple Remote was originally designed to interact with?',
#  '5ae2070a5542994d89d5b313': 'Which performance act has a higher instrument to person ratio, Badly Drawn Boy or Wolf Alice?',
#  '5ae22b8d554299234fd0440f': 'What was the father of Kasper Schmeichel voted to be by the IFFHS in 1992?',
#  '5a722b8655429971e9dc9329': "Who was the writer of These Boots Are Made for Walkin' and who died in 2007?",
#  '5adf37a95542995ec70e8f97': "The 2011–12 VCU Rams men's basketball team, led by third year head coach Shaka Smart, represented Virginia Commonwealth University which was founded in what year?",
#  '5abd259d55429924427fcf1a': 'Are both Dictyosperma, and Huernia described as a genus?',
#  '5a828c8355429966c78a6a50': 'Kaiser Ventures corporation was founded by an American industrialist who became known as the father of modern American shipbuilding?',
#  '5a8a3e745542996c9b8d5e70': 'What is the name for the adventure in "Tunnels and Trolls", a game designed by Ken St. Andre?',
#  '5ac23ff0554299636651994d': 'When was Poison\'s album "Shut Up, Make Love" released?',
#  '5ae4a3265542995ad6573de5': 'Hayden is a singer-songwriter from Canada, but where does Buck-Tick hail from?',
#  '5ae0361155429925eb1afc2c': "Which  French ace pilot and adventurer fly L'Oiseau Blanc",
#  '5abc0a5d5542993f40c73c64': 'Are Freakonomics and In the Realm of the Hackers both American documentaries?',
#  '5a7cc50e554299452d57ba3e': 'Which band, Letters to Cleo or Screaming Trees, had more members?',
#  '5abf63f15542997ec76fd3ea': 'Alexander Kerensky was defeated and destroyed by the Bolsheviks in the course of a civil war that ended when ?',
#  '5a8ef2a75542995a26add583': 'Seven Brief Lessons on Physics was written by an Italian physicist that has worked in France since what year?',
#  '5a80721b554299485f5985ef': 'The Livesey Hal War Memorial commemorates the fallen of which war, that had over 60 million casualties?',
#  '5ab51dae5542991779162d82': 'Are both Elko Regional Airport and Gerald R. Ford International Airport located in Michigan?',
#  '5a7571135542992d0ec05f98': 'Ralph Hefferline was a psychology professor at a university that is located in what city?',
#  '5a7a0e1e5542990783324e1a': "Which dog's ancestors include Gordon and Irish Setters: the Manchester Terrier or the Scotch Collie?",
#  '5a74106b55429979e288289e': 'Where is the company that Sachin Warrier worked for as a software engineer headquartered?',
#  '5a79311755429970f5fffe67': 'A Japanese manga series based on a 16 year old high school student Ichitaka Seto, is written and illustrated by someone born in what year?',
#  '5ab2d3df554299194fa9352c': 'The battle in which Giuseppe Arimondi lost his life secured what for Ethiopia?',
#  '5a760ab65542994ccc918697': 'Alfred Balk served as the secretary of the Committee on the Employment of Minority Groups in the News Media under which United States Vice President?',
#  '5a7d54165542995f4f402256': 'A medieval fortress in Dirleton, East Lothian, Scotland borders on the south side of what coastal area?',
#  '5ab859a955429934fafe6d7b': 'Who is the writer of this song that was inspired by words on a tombstone and was the first track on the box set Back to Mono?',
#  '5add61d65542995b365fab21': 'What type of forum did a former Soviet statesman initiate?',
#  '5a8e068b5542995085b37384': 'Are Ferocactus and Silene both types of plant?',
#  '5abbf698554299114383a0b5': 'Which British first-generation jet-powered medium bomber was used in the South West Pacific theatre of World War II?',
#  '5a8e1027554299653c1aa15f': 'Which year and which conference was the 14th season for this conference as part of the NCAA Division that the Colorado Buffaloes played in with a record of 2-6 in conference play?',
#  '5ab84bf555429916710eb01f': 'In 1991 Euromarché was bought by a chain that operated how any hypermarkets at the end of 2016?',
#  '5a77724455429972597f153e': 'What race track in the midwest hosts a 500 mile race eavery May?',
#  '5a87c13f5542996e4f30890c': 'In what city did the "Prince of tenors" star in a film based on an opera by Giacomo Puccini?',
#  '5ab96ab755429970cfb8eacd': 'Ellie Goulding worked with what other writers on her third studio album, Delirium?',
#  '5a8a43eb5542996c9b8d5e82': 'Which Australian city founded in 1838 contains a boarding school opened by a Prime Minister of Australia and named after a school in London of the same name.',
#  '5ae73acb5542991e8301cc07': 'D1NZ is a series based on what oversteering technique?',
#  '5a7320565542991f9a20c61d': 'who is younger Keith Bostic or Jerry Glanville ?',
#  '5ae32e125542991a06ce9946': 'According to the 2001 census, what was the population of the city in which Kirton End is located?',
#  '5adc53f75542996e6852530a': 'Are both Cypress and Ajuga genera?',
#  '5a8b20335542996c9b8d5fb3': 'What distinction is held by the former NBA player who was a member of the Charlotte Hornets during their 1992-93 season and was head coach for the WNBA team Charlotte Sting?',
#  '5a85fb085542994775f606de': 'What is the name of the executive producer of the film that has a score composed by Jerry Goldsmith?',
#  '5a7be2595542997c3ec972ac': 'Who was born earlier, Emma Bull or Virginia Woolf?',
#  '5a77152355429966f1a36c2e': 'What was the Roud Folk Song Index of the nursery rhyme inspiring What Are Little Girls Made Of?',
#  '5abfb3425542990832d3a1c0': 'Andrew Jaspan was the co-founder of what not-for-profit media outlet?',
#  '5ac3165c5542995ef918c10a': 'Which American film director hosted the 18th Independent Spirit Awards in 2002?',
#  '5ae53b545542990ba0bbb23c': "Where does the hotel and casino located in which Bill Cosby's third album was recorded?",
#  '5ae224da554299234fd043ee': 'Do the drinks Gibson and Zurracapote both contain gin?',
#  '5ae2b770554299495565db0f': 'In what month is the annual documentary film festival, that is presented by the fortnightly published British journal of literary essays, held?',
#  '5a80b3a9554299485f5986cc': 'Tysons Galleria is located in what county?',
#  '5a8e0a005542995085b373a1': 'Bordan Tkachuk was the CEO of a company that provides what sort of products?',
#  '5ac1b8ee5542994d76dccedc': 'Which filmmaker was known for animation, Lev Yilmaz or Pamela B. Green?',
#  '5adccd795542990d50227d2c': 'In which city is the ambassador of the Rabat-Salé-Kénitra administrative region to China based?',
#  '5a84c4135542994c784dda31': 'Are Yingkou and Fuding the same level of city?',
#  '5a85eed75542996432c5713b': 'Where did the descendants of the group of black Indians associated with the Seminole people settle?',
#  '5a774e9c55429972597f14f3': 'David Huntsinger has worked with this gospel singer born in the month of July?',
#  '5ae738f75542991bbc9761c4': 'What year was the brother of this first round draft pick by the Washington Redskins drafted?',
#  '5ac32b565542995ef918c154': 'Where is the stadium at which 1964 Georgia Tech Yellow Jackets football team played their home game located?',
#  '5abc8d75554299700f9d7900': 'Since 2 June 2017, The Leader of Fine Gael had been held by which Irish Fine Gael politician who has served as Taoiseach and Minister for Defence?',
#  '5a8bb29b554299240d9c2089': 'Which American film actor and dancer starred in the 1945 film Johnny Angel?',
#  '5ab659e355429954757d324e': 'hree Men on a Horse is a play by a playwright born in which year ?',
#  '5a8b8b3155429949d91db5d7': 'What type of activity does Owner earnings and Warren Buffett have in common?',
#  '5ae7eaf65542994a481bbe1d': 'When was the  former Indian cricketer who made his ODI debuts during the 2000 ICC KnockOut Trophy born?',
#  '5a8c4c625542995e66a475a1': 'Which airplane was this Major test-flying after whom the base, that 514th Flight Test Squadron is stated at, is named?',
#  '5a818387554299260e20a291': 'Based on a True Story... is an album by which country music star, with the single My Eyes?',
#  '5ab978855542996be2020512': 'Over how many centuries were the "dwelling place of the dead" built?',
#  '5ae63dad55429929b0807afe': 'When was the British author who wrote the novel on which "Here We Go Round the Mulberry Bush" was based born?',
#  '5a7a455c5542994f819ef1a7': 'Who died first, George Archainbaud or Ralph Murphy?',
#  '5a7dcc775542990b8f503ab5': 'Which component of shellite has the formula (ON)CHOH?',
#  '5a887bc0554299206df2b2b6': 'The Argentine PGA Championship record holder has won how many tournaments worldwide?',
#  '5a83880e554299123d8c214e': "Suicide's 1977 released album features a song based on what brand's comic character?",
#  '5a879adb5542996e4f30887f': 'What other political position did the person who introduced the DISCLOSE Act hold?',
#  '5add11935542994734353827': 'Were the bands Skin Yard and Ostava from the U.S.?',
#  '5a8c5569554299240d9c2126': 'Are Daryl Hall and Gerry Marsden both musicians?',
#  '5a75f0ea5542994ccc91866c': 'What major truck road is located in Backford Cross?',
#  '5ab6ba245542995eadef007f': 'Are Bamboo Mañalac and Danny Jones both musicians?',
#  '5ab8854555429934fafe6e0c': 'Works by Hanna Leena Kristiina Varis are part of a collection in a museum that houses approximately 65,000 what?',
#  '5a8eea4a5542990e94052bb7': 'When was the Western Germanic language spoken from which the small settlement situated on the river Leda opposite Leer derives its name?',
#  '5a74c85055429916b0164218': 'Born on 6 March 1937, this man was also a citizen of the United Kingdom.',
#  '5a88dcf9554299206df2b383': 'What country does Hatton Hill and Hatton Castle, Angus have in common?',
#  '5a7625c7554299109176e668': 'What podcast was the cheif executive officer of Nerdist Industries a guest on?',
#  '5ac0d83a554299294b219038': 'Randall Cunningham II was a multi-sport athlete at the high school located in what Nevada city?',
#  '5a790d8f554299029c4b5eec': 'Which English musician is known for both the songs "See Yourself" and "Withing You Without You"?',
#  '5ab2c5e255429916697740ba': 'Which professional ice hockey position does the Captain of the National Hockey League All-Star Game "Away Team" play?',
#  '5abcfc365542993a06baf9d6': 'What year did the series on CBS, starring the actor who known for his role in "Rebel Without a Cause," air?',
#  '5a8ee6915542990e94052bad': 'What season was the character introduced that becomes the main antagonist in the  following season, from the animated television series created by Bryan Konietzko and Michael Dante DiMartino as a sequel to "", which aired from 2005 to 2008?',
#  '5abba4855542993f40c73b68': 'Who were the directors of the 2009 American science fiction film starring the actor who played Dexter Morgan in the Showtime TV Network series "Dexter"?',
#  '5ae0bae555429906c02dab08': 'Which travel parody series featured American actor, comedian, and radio host best known as the host of "The Joe Schmo Show"?',
#  '5ab271fe554299449642c8a6': 'Do The Importance of Being Icelandic and The Five Obstructions belong to different film genres ?',
#  '5a7997a2554299029c4b5f59': 'Tefik Selim Mborja was a part of a party that held power in Albania until what year?',
#  '5add673e5542992ae4cec54d': 'Joe Walker played for which team that ends their regular season with the Civil War rivalry game?',
#  '5ae819ac55429952e35eaa16': 'What station broadcast the episode "Marry Me a Little, Marry Me a Little More" , of the series created by Max Mutchnick and David Kohan?',
#  '5aba65a055429939ce03dcd2': 'Georges-Henri Bousquet translated the work of a historian who is of what heritage?',
#  '5a87bada5542994846c1cddc': 'In which city are the headquarters of the American research and scientific development company where Ravi Sethi worked as computer scientist located?',
#  '5ae74fc45542997b22f6a6b4': "What is the full name of the viral respiratory disease in which Yi Guan's research helped to prevent the outbreak of?",
#  '5adf65555542992d7e9f9334': 'Which Kentucky Writers Hall of Fame author has had works published by Dim Gray Bar Press?',
#  '5ade69e455429975fa854ec5': 'What director worked with Vikram Bhatt on a film starring actors Rajneesh Duggal and Adah Sharma?',
#  '5ae057fd55429945ae959328': 'Robert Smith founded the multinational company headquartered in what city?',
#  '5ab28019554299722f9b4d51': 'What amount was the settlement that the character from the Son of al Quada got in 2017?',
#  '5a75f79555429976ec32bcca': 'Considered the strongest recorded tropical cyclone, which cyclone had a film made about it in 2007?',
#  '5adef80b5542993a75d263c4': 'The 2000 British film Snatch was later adapted into a television series for what streaming service?',
#  '5ae0aaf455429945ae959401': 'Chris Williams last played for which football club from the National League North?',
#  '5ab47d765542991751b4d78f': 'Who designed the hotel that held the IFBB professional bodybuilding competition in September 1991?',
#  '5a7ed2c655429930675135e5': 'At the 71st Golden Globe Awards for television in 2013, what achievement did Breaking Bad, police sitcom Brooklyn Nine-Nine and American Hustle attain?',
#  '5ac3e0f7554299194317388b': 'Which actor does American Beauty and American Beauty have in common?',
#  '5a7bae20554299294a54aa96': 'Onika Tanya Maraj is a judge on a television show hosted by whom?',
#  '5ab8ee035542991b5579f04b': 'Are Hot Rod and The Memory of Our People both magazines?',
#  '5a7a276d5542996c55b2dd27': 'Who was Chamberlain and Colonel of the military staff of The Merrie Monarch?',
#  '5a717d4c5542994082a3e854': 'Who has written more than 300 papers, Semyon Aranovich Gershgorin or Pavel Alexandrov?',
#  '5ac02e31554299294b218f3f': 'Which post DC Extended Universe actress will also play a role in what is intended to be the fifth installment of the DC Extended Universe?',
#  '5a79ea435542996c55b2dc9e': 'Who was the captain of the only battleship to provide gunfire support during the Vietnam War?',
#  '5ab7e4dc5542995dae37e9df': 'The Polar Bears featuring the voice of Armie Hammer, is also the same voice actor for which character in Cars 3?',
#  '5a834ed95542990548d0b1ca': 'Which tower is taller, 712 Fifth Avenue or Manhattan Life Insurance Building?',
#  '5ab41d855542996a3a969f4b': 'Is the Pakistan fast bowler who joined the Kent County Cricket Club in June, 2011 a left-hand or right-hand batsmans?',
#  '5a7b7ff75542995eb53be93d': 'Who was born first, Arthur Conan Doyle or Penelope Lively?',
#  '5a7d19d85542995ed0d165e8': 'The Tennessee Volunteers football team plays as a member for a conference in what city?',
#  '5ae7ed17554299540e5a56a3': 'Ernest Foot was the best friend of the fighter pilot who had how many victories?',
#  '5ab2659e554299340b5254b2': 'From March 631 to April 631, Farrukhzad Khosrau V was the king of an empire that succeeded which empire?',
#  '5abd2eab5542992ac4f38210': 'Which suburb is a soap opera featuring a character named Beverly Marshall set in?',
#  '5abaf3195542996cc5e49f2c': 'Which country did the Falkland Islands beat in the 2010 Commonwealth games that has eleven administrative divisions?',
#  '5a791a97554299148911f9f2': 'Which Netflix series "Unbreakable" character is Elizabeth Claire Kemper known for playing?',
#  '5adf58f15542993a75d264d2': 'Which television series featured an actor who also performed in "The Young Ones"?',
#  '5adc65e85542996e68525350': 'Are both Dafeng District and Dazhou located in the same province?',
#  '5a87ab9b5542996e4f3088c2': 'In what century did this Native warrior and chief, whose brother Tenskwatawa led the Tippecanoe order of battle, become the primary leader of a large, multi tribal confederacy?',
#  '5a738fe855429908901be2fb': 'What film was written and directed by Joby Harold with music written by Samuel Sim?',
#  '5a8c65a1554299585d9e3680': "What is the name of the ethnic group who settled in Canada in the 17th century that participated in a conflict with Irish Catholic immigrants in the Shiners' War?",
#  '5ac2bbd0554299218029db09': 'The author of The Thing of It Is... is what Nationality?',
#  '5adf3e355542993a75d26440': 'How long is the bridge in the Öresund Region that connect Copenhagen, Denmark and Malmo, Sweden?',
#  '5ae82ae555429952e35eaa71': 'Martin Patterson "Pat" Hingle was a close friend of an actor who achieved success in what Western TV series?',
#  '5a7a46605542994f819ef1ad': 'What year did Roy Rogers and his third wife star in a film directed by Frank McDonald?',
#  '5ade7a435542997c77adee3a': 'The name "Mountbatten-Windsor" applies to male-line descendants of the Queen without royal styles and titles which is a Eurpean dynasty resulting in what family?',
#  '5ac1795f5542994ab5c67d5f': 'Who is known for producing the documentary television series based on the book by science historian James Burke?',
#  '5ab1e984554299340b525428': 'which is larger Asante Traditional Buildings or Gulangyu?',
#  '5a86769c5542994775f60776': 'Armageddon in Retrospect was written by the author who was best known for what 1969 satire novel?',
#  '5ab7da6f55429928e1fe3928': 'Patrick Kennedy is known for his collections of Irish  folktales from a province situated in which part of Ireland ?',
#  '5ae497f15542995ad6573db8': 'What NIFL Premier Intermediate League team did Sean Connor play for?',
#  '5ae6f2a7554299572ea5464a': "Which character does this protagonist, who secretly loves and marries a member of the rival house, of William Shakespeare's tragedy that has a fictional character Benvolio slay?",
#  '5adea9ea55429939a52fe934': 'What was the name of the fanzine that interviewed the Sex Pistols bassist when he was in the band "The Flowers of Romance?"',
#  '5a7caae75542996dd594b971': 'What, known as AAS, is commonly used in bodybuilding?',
#  '5ac01bb8554299012d1db5a6': 'Which American character actor who starred on the television series "Stargate SG-1" (1997–2007) and appeared in "Episode 8" of "Twin Peaks" as a guest star?',
#  '5abc3a65554299700f9d782d': 'Candy Coburn has shared the stage with an American country music group with who playing guitar?',
#  '5ae3ff575542995dadf242aa': 'What is the population according to the 2007 population census of the city in which the National Archives and Library of Ethiopia is located?',
#  '5a89fb525542993b751ca9d6': 'Which composer created Night Ferry first performed in 2012 at Symphony Center in Chicago?',
#  '5ab3d69255429969a97a81c9': 'To which aircraft carrier was the VMF-213 Marine Fighting Squadron assigned to durning World War II?',
#  '5ac5199a5542994611c8b38a': 'Can Stenocereus and Pachypodium both include tree like plants?',
#  '5ae048a255429924de1b708e': 'What movie did Pitof direct which had an action-adventure tie-in video game based off of it in 2004?',
#  '5a9068a95542990a98493621': 'on 16 January 1995 "First Knight" was being filmed at a studio located how far from Windsor ?',
#  '5adf9dc3554299025d62a2e6': 'What is the name of the actress who has received a Drama Desk award and was part of the cast album for the 2007 Broadway production of the hit musical, "Grease"?',
#  '5ae406245542995dadf242e2': 'Marion Greene was a health policy analyst for St. Judt Medical company, which had how many principal operations worldwide?',
#  '5ab6369655429953192ad2a1': 'Which Genus has more species Eucryphia or Lepidozamia ?',
#  '5ae628f55542995703ce8b32': 'In what city was the Italian Baroque composer who composed a set of sonatas, titled Op. 5, born?',
#  '5adccdd55542992c1e3a2408': 'Meaning "reddish water" in Hawaiian, which location was Butch Van Artsdalen known for surfing 25-foot waves at?',
#  '5abd1529554299114383a1e3': 'What type of magazine is Eugene Habecker the chairman of?',
#  '5a78db8055429970f5fffdb2': 'Flyboys stars which actor who was nominated for an Academy Award for "127 Hours"?',
#  '5ab9debb55429955dce3ed97': 'The English actor Kris Marshall played which character in the highly rated comedy-drama television series "Death in Paradise"?',
#  '5ae791ef55429952e35ea979': 'In what month was the relief first officer of the flight that crashed on its way to Cairo with a stop in New York Born?',
#  '5ab8f7535542991b5579f0a7': 'Which film was released first: Sacred Planet or Oz the Great and Powerful?',
#  '5ac119335542992a796dede4': "I'd Come for You is a single by the band formed in what Alberta city?",
#  '5a7d2afd5542995f4f402221': 'Who is older, Ferdi Taygan or Mahesh Bhupathi?',
#  '5a8dd5f955429917b4a5bcc7': 'Other than racing, what sport does the 1998 champion of the Toyota GRand Prix practice?',
#  '5a83a532554299334474606f': 'Where did Ian Harland study prior to studying at the oldest college at the University of Cambridge?',
#  '5a90692f5542990a98493625': 'In what 1997 American mystery crime film did Johnny Galecki start in?',
#  '5a7555215542996c70cfaee1': 'Which came to market first, "Hey Pa! There\'s a Goat on the Roof" or "Poleconomy"',
#  '5a90580655429933b8a204ef': 'What record did the Super Bowl XXXIV champions finish the regular-season with in 1999?',
#  '5a88e605554299206df2b39c': 'What is the population of the town at the intersection of Interstate Highways 77 and  the longest Interstate highway within the borders of Virginia?',
#  '5add67915542992200553af8': 'What was the nickname of the hitman hired by an Italian American Criminal Organization?',
#  '5a8463545542990548d0b2a3': 'What was the position of Jean Baptiste Androuet du Cerceau under the man who was King of the Polish-Lithuanian Commonwealth from 1573 to 1575?',
#  '5a74684655429929fddd8410': 'Which American music star appeared as a guest in a Will & Grace episode called "Back Up, Dancer"?',
#  '5a835c9f5542992ef85e228a': 'What army did the namesake of the ship launched as the München in 1930 fight in during the American Revolutionary War?',
#  '5ae7edee554299540e5a56ad': 'The Church of the Guanche People was founded in the city that is on the most populated island of what larger area?',
#  '5a8ee4315542990e94052ba7': 'What officially ended the first phase of the military conflict between the British Raj and the Emirate of Afghanistan from 1878 to 1880?',
#  '5a8cb288554299585d9e3726': 'The mass killing that took place at Oakland, California on April 2, 2012 was less deadly than the one that took place on October 1, 2015 in which state?',
#  '5adfbca255429942ec259b2c': 'When did the rock band that sang "All Join Hands" rise to prominence?',
#  '5ae24abc5542994d89d5b3c3': 'Where is the company that owns thanKing Horse pub restaurant chain based ?',
#  '5ab802085542990e739ec7ca': 'What is the uppermost age range for the sort of fiction written by Alexander Gordon Smith?',
#  '5adfa3da554299025d62a317': 'What is the birthday of the actress who was the Duchess in "The Revengers Tragedy"?',
#  '5a76e88555429972597f13f4': 'Which film starring Patrick Tatten is based on a book written by Steve Lopez?',
#  '5ac3ae475542995ef918c1e5': 'Are Skeptical Inquirer and The Progressive Populist both tabloid-style magazines?',
#  '5abffc41554299012d1db551': 'The 1984 film "Marlene" is a documentary about an actress born in what year?',
#  '5ae4c39f5542995dadf243fb': 'Which former mill town is near Rivington Hall Barn?',
#  '5a79c6a55542994bb9457091': 'What prolific English engineer, who died on 15 December 1857, contributed to the advent of the hot air engine by way of their open cycle devices?',
#  '5a7be5bd5542997c3ec972ba': 'Which dog is considered a giant dog breed, the  Leonberger or the Basset Hound?',
#  '5a7ec61a55429934daa2fc5f': 'Are Staten Island Catapult and This Is Elvis both documentaries?',
#  '5a7cb9b95542990527d55515': 'What is the year of the event that occured first, Making Today a Perfect Day was produced, or Frozen was produced?',
#  '5a867089554299211dda2b30': 'Which magazine is published more often, Shonen Jump or Rolling Stone?',
#  '5ae1801955429901ffe4aec4': 'Where is the Cocoa Krispies and former Superman sponsor located?',
#  '5a76387d554299109176e6ba': 'Who was born first Am Rong or Ava DuVernay ?',
#  '5abd0d635542992ac4f381b8': 'How many days did it take the Best New Artist of 2009 to sell 2 million copies of an album in the UK and break a twenty year old record?',
#  '5ae68fcb5542992ae0d1635b': '"Ew!" is a song by a television host born where?',
#  '5ab28b12554299449642c8ee': 'The northern English anglian Kingdom in the Humber estuary spoke what dialect of english?',
#  '5a7133565542994082a3e65c': 'What Kentucky county has a population of 60,316 and features the Lake Louisvilla neighborhood?',
#  '5abbd3ac55429931dba1458b': 'Are both Duke Energy and Affiliated Managers Group based in Massachusetts?',
#  '5a85ab905542994c784ddb35': 'Two positions were filled in The Voice of Ireland b which British-Irish girl group based in London, England?',
#  '5a8d93ad554299653c1aa13d': 'Who was also an actor, Serri or John Fogerty?',
#  '5a886886554299206df2b258': 'What is the international football competition for women that Liu Ailing played in the 1991,1995, 1999 editions?',
#  '5a7c6bcc55429935c91b519c': 'Rock Springs is a collection of short stories by an author born in what year?',
#  '5a825bb455429940e5e1a874': 'Folie à Deux is a studio album by the American rock band formed in which city?',
#  '5a72a0be5542992359bc3143': 'This work of literature _______ , known by its Greek title Oedipus Tyrannus was argued by Sigmund Freud to be one of the greatest works of world literature in his 1928 article.',
#  '5ade15f35542997545bbbe47': 'Katherine Waterston and Chrisann Brennan has what in common?',
#  '5a77cb5e55429967ab1052a7': 'The voice of Homer Simpson also voices what alien character in the television series "The Simpsons"?',
#  '5a83aaeb5542996488c2e483': 'What studio album did Kanye West record with Roc-A-Fella Records and soul singer Dwele?',
#  '5ac4392e5542997ea680ca32': 'Were Enrique Carreras and Lionel Ngakane both filmakers during the 20th century?',
#  '5a7f5c9f55429969796c1a0f': 'The city that contains the Yunnan Provincial Museum is also known by what nickname?',
#  '5a8b770f5542995d1e6f13a7': 'Where is the singer of "B Boy" raised?',
#  '5ae3dc205542992f92d823a1': 'The Column of Saint Zanobi  is a monumental marble column located just north of religious building with the status of what?',
#  '5a7cf29255429909bec768b8': 'The Ingerophrynus gollum is named after a character in a book that sold how many copies?',
#  '5a79f6ca554299029c4b5f90': 'What Danish eurodance group had a single called "Barbie Girl" which resulted in a lawsuit in 2002?',
#  '5a8e3dc05542995085b37401': 'Which case was decided first, Selle v. Gibb or Reynolds v. Sims?',
#  '5ade24e35542992fa25da6e6': 'Mamie Gummer played the role of Nancy Crozier on the TV series airing on what network?',
#  '5ab5f854554299637185c64e': 'What country do both Adnan Akmal and Kamran Akmal represent in cricket?',
#  '5ab5b6c1554299637185c5e5': 'Did Franki Valli sing with Hellogoodbye or The Four Seasons?',
#  '5ae25ed15542992decbdccd2': 'Both Sorbaria and Goldenrod are a genus of more than 50 flowering plants?',
#  '5ab808ea5542991d3222380e': 'What is the capacity of the Stadium, other than Kauffman Stadium, designed by Charles Deaton ?',
#  '5ac3d9c9554299204fd21ea3': 'Erica Packer was the second wife of what Australian businessman?',
#  '5abc8620554299700f9d78e2': 'What type of media does Bitter Jester and Sicko have in common?',
#  '5a7b4bc35542992d025e67e0': 'What country does Eric A. Sykes and Eccles, Greater Manchester have ion common?',
# ...
#  '5ae10df355429920d52342ac': "Where was the host of Australia's Got Talent born?",
#  '5ae4d8475542993aec5ec0e0': 'Repertoire of Plácido Domingo appeared in an opera written by whom which was based on a play by William Shakespeare?',
#  '5ab94cf0554299743d22eade': 'Naval Air Station Ellyson Field was an auxiliary facility to the air station in which community?',
#  '5ae479745542996836b02cb1': 'What is the name of the movie that stars Katrina Bowden and was directed by Sean Anders?',
#  '5a852cd05542997b5ce3ffb0': 'The birthplace of George McCall Theal is a port city of what bay?',
#  '5a8babf05542996e8ac8899e': 'Whose native growing land is more south, Beech or Daviesia?',
#  '5a82fcbd55429954d2e2ebe8': 'Russia Soviet pianist, composer and teacher, Tatiana Nikolayeva taught what Polish pianist and music educator?',
#  '5a77c60255429967ab105285': 'What theory was advanced by the author of Progress in Optics?',
#  '5adf39ce5542995534e8c76d': "What did Karan Kapoor's maternal grandfather deliver?",
#  '5ae694a15542991bbc976141': 'Why is Minister Pool important to Black Country and the West Midlands in England?',
#  '5ae13bca55429901ffe4ae17': "Which American singer-songwriter toured with J.P. Doherty in 2007 on Cyndi Lauper's True Colors tour?",
#  '5a8a265b5542992d82986ecc': 'Between Frederick King Keller and Ian Schneider, which filmmaker had more diverse job experiences?',
#  '5a77121a5542994aec3b71db': "Which 1970's film was released first, Charley and the Angel or The Boatniks?",
#  '5ae6911955429908198fa626': 'M.F.A. starred the actress known for starring in what E! reality series?',
#  '5ae53de455429908b6326599': 'The creek of which Paradise Creek is a tributary is a tributary of what river?',
#  '5a813b6f55429903bc27b951': 'What tribe was the Megaoryzomys curioi previously in that Nesoryzomys are also in?',
#  '5a84b4005542991dd0999d99': 'When did the Disney sitcom in which Genevieve Knight "G" Hannelius starred as Avery Jennings end?',
#  '5a8cca64554299653c1aa125': 'who were James Hill and John Vereker, 6th Viscount Gort officers for?',
#  '5ab8ed305542991b5579f046': 'Keene is an unincorporated community in Wabaunsee County, Kansas, in what federal republic composed of 50 states?',
#  '5ae0b2f25542993d6555ec1c': "What food does one of Daniel Greene's subjects' restaurant chain specialize in?",
#  '5ae207a65542994d89d5b317': 'In which genus number of species are more, Lavatera or Oplismenus?',
#  '5a75383a5542996c70cfaeb3': 'Who was born first, Ulf Merbold or Mirosław Hermaszewski?',
#  '5ae3fd2c5542995dadf2428f': 'Are Ian Brown and Dee Snider both actors?',
#  '5abffd10554299012d1db556': 'What Italian region does Slinzega come from?',
#  '5a8f812755429918e830d245': "What was Robert M. Fomon's connection to the New York Stock Exchange located at 11 Wall Street, Lower Manhattan, New York City, New York?",
#  '5ae520315542993aec5ec152': 'Liz Rose has co-written songs with which artist including "White Horse" and "You Belong with Me"?',
#  '5a7631cd5542994ccc91870c': 'Where is the seminar Jeanne Marie Beaumont directed in 2007-2010 located?',
#  '5ac26eed55429951e9e685bf': 'where is the  a county where  Purcell can be found located',
#  '5a7e37095542995ed0d166d5': 'Which film director is younger, Robert Z. Leonard or Sinclair Hill?',
#  '5adf72d35542992d7e9f9369': 'Are William Kronick and Jon Turteltaub both television writers ?',
#  '5a876b265542993e715abf33': 'Who was a more acclaimed guitarist Stephen Christian or Joe Gooch?',
#  '5a77ddb855429967ab1052d8': 'The True Colors World Tour was by what artist whose debut album was "She\'s So Unusual"?',
#  '5adcc3ed5542994d58a2f6c4': 'What group did Carlene LeFevre and Rich LeFevre form in Brooklyn, New York City?',
#  '5a76f5b155429972597f1400': 'What American composer born in 1937 pioneered minimal music?',
#  '5ae2c696554299495565db32': 'What political office was held by two successive occupants of the same castle located in Lauderdale, Scotland?',
#  '5a875154554299211dda2be7': "Who founded the honky tonk that is at the center  of John Travolta's  third major acting role?",
#  '5a84cf175542992a431d1aa2': 'Which band has more constant members, Lilys or Ratatat?',
#  '5ae675245542991bbc9760dc': 'What is the name of the father of Childericus?',
#  '5a80b0565542996402f6a5f0': 'Which band was formed first, Lit or Adorable?',
#  '5adde3a45542997545bbbdc2': 'Are both Delmer Daves and Jean-Pierre Jeunet film directors?',
#  '5ac26b7f55429951e9e685ae': 'who influenced the electronic dance music who  made  Scotch Hausen album',
#  '5adf39295542992d7e9f92df': 'Which genus has more species, Apium or Elodea?',
#  '5abc19705542993a06baf86e': 'Black Book starred the actress and writer of what heritage?',
#  '5ae6914755429908198fa627': 'Brian Olsen was the lst WEC heavyweight champion before the promotion company founded in what month purchased the organization?',
#  '5adc9b7a5542994d58a2f679': 'Shani Gandi has worked with Kelsea Ballerini in what country?',
#  '5a721dfd55429971e9dc928b': "Which of Kylian Hazard's older brothers plays for the German Bundesliga club Borussia Mönchengladbach and the Belgium national team.",
#  '5a8b50475542997f31a41cd4': 'Wing Chun starred Michelle Yeoh and a Hong Kong actor, martial artist, and film director who won what tournament multiple times?',
#  '5a860aa6554299211dda2a45': 'Which publication publishes more frequently, Utne Reader or The New York Enterprise Report?',
#  '5ae4585c5542996836b02c89': 'Which band has more members Band of Skulls or Live ?',
#  '5adfcb5455429906c02daa48': 'What character in "Father Ted" was played by an actor who starred in Death in Paradise?',
#  '5a77a41a5542997042120ab9': "What year did Christopher Nolan's magic-themed drama come out?",
#  '5a8759395542994775f607e0': 'Who is older between the brothers that J. Todd Anderson has primarily worked with?',
#  '5a84992e5542992a431d1a6d': 'Who owns the hotel where the 13th Anniversary Show took place?',
#  '5ac1bce45542994ab5c67def': 'Are Pothos and Tibouchina Aubl both flowering genus of plants?',
#  '5ac0641f554299294b218fbe': 'Immanuel Lutheran School is affiliated with the denomination that has how many members?',
#  '5a87954f5542996e4f308856': 'Which genus has more species, Bactris and Epigaea?',
#  '5a8bc03d5542996e8ac88a0b': 'What was the code name of The landing barge primarily used to provide hot meals to the landing crew?',
#  '5ab8869155429916710eb081': 'Electronic Attack Squadron 138 is a type of which American carrier-based electronic warfare aircraft, a specialized version of the two-seat F/A-18F Super Hornet?',
#  '5adde17f5542992200553b87': "For which NBA team did the MVP of the 2013 McDonald's All-American Boys Game play?",
#  '5a776ac75542993569682d9b': 'Who was elected more times, Daniel Patrick Moynihan or Dennis Kux?',
#  '5ae70ed7554299572ea546a1': 'Victor Varnada directed Twisted Fortune, which starred which brother of Eddie Murphy?',
#  '5ae1fbf05542997f29b3c1e7': 'When was the American automobile club which has 2014 Trans-Am Series as the 46th running of the Sports formed?',
#  '5ac1c9a15542994ab5c67e1c': 'What is the population of the city in which the first edition of the South American Youth Olympic Games were held?',
#  '5a77c8905542995d831812ce': 'Who constructed Auburn the Antebellum mansion and was accused of the Manhattan Well Murder?',
#  '5a89f68f5542992e4fca84b6': 'What kind of person of authority does Governor of Sheerness and Stapleton Cotton, 1st Viscount Combermere have in common?',
#  '5a7f62405542992e7d278cf0': 'What was the name of the publisher who published "Finnegans Wake" in 1939 by James Joyce',
#  '5a7ca4485542990527d554f1': 'What was the address of the penitentiary where Jimmy Elliot was sentenced?',
#  '5a8347d65542996488c2e3f6': 'in the 2004 Hockey film produced by a former major league baseball pitcher who played the USA coach?',
#  '5ab8634e5542990e739ec8de': 'In regards to Value premium an expert argued that no value premium exisits, what did this expert found?',
#  '5ab85e9e55429934fafe6d8b': 'What is the founding year of this public research university in the Netherlands, where Jan Borgman was a professor from 1968 to 1988?',
#  '5a79c9c05542994bb94570a5': 'This man who was born on April 25th, 1947, was a member of this lower house of the Hawaii State Legislature.',
#  '5a8c616f5542995e66a475de': 'Which road borders both Pacific Mall and Splendid China Mall ?',
#  '5ab90fdd55429916710eb0fc': 'Wheelock Whitney is just one member of the Whitney Family. Where did this American family originate from?',
#  '5abe7f695542993f32c2a12d': 'What is the focus of the movie in which Nolan North played the role of Superboy?',
#  '5abeb0da5542997ec76fd34b': 'Were both Monkey Kingdom and Anaganaga O Dheerudu connected with Disney?',
#  '5a7521c55542993748c897c6': 'Temagami-Lorrain Mine and Burwash Mine were both mines created during the early 1900s; which one yielded a 16-ton bulk sample of gold ore in 1935?',
#  '5adfda5255429942ec259b5e': 'What county in Minnesota holds a 202 lb slab of greywacke covered in runes?',
#  '5abaeda95542992ccd8e7e5d': 'What is the fictional name of the mall in the movie "Back to the Future" which was filmed at the headquarters of EverTrust Bank?',
#  '5ae68e0055429908198fa607': 'Tamanchey is a comedy film that starred the actress who works in what type of films?',
#  '5a7577785542992d0ec05fa0': 'The Northern Chamber Orchestra gives concerts at what estate owned by the National Trust?',
#  '5a7d147955429909bec76942': 'Which star of "Chalet Girl" also appeared in "The Treasure Seekers"?',
#  '5a83a2a15542993344746063': 'In regards to the high school that forced Manchester High School to change its name in 1922, when was its first graduating class?',
#  '5ac079e9554299294b218fff': 'What organization does Rosyth Dockyard and Queen Elizabeth-class aircraft carrier have in common?',
#  '5adca8375542990d50227cd4': 'What year was the song that some critics compared to "Fading" released?',
#  '5add4f3a5542997545bbbd2c': 'What is another name for the LRA featured in A Brilliant Genocide?',
#  '5ae26cb15542994d89d5b421': 'Charlie McDermott plays Axl Heck on a tv show that premiered in what date?',
#  '5a73cad5554299623ed4ac5e': 'What Dances with the Wolves star had a role in Powwow Highway?',
#  '5ae0d5335542990adbacf674': 'Who created the show that featured Triumph the Insult Comic Dog?',
#  '5ab344fc55429969a97a811e': 'Do Bloody Mary and Sidecar share any ingredients in common?',
#  '5ae1319c55429920d5234301': 'The tap dancing soloist in My Feet Keep Dancing also starred in what 1935 MGM musical?',
#  '5abee41a5542993fe9a41d79': 'What type of auto racing, performed on clay or dirt surfaced oval tracks, is run for the Australian Street Stock Championship?',
#  '5a7daad55542995f4f4022b7': 'What year was the namesake of a small island in the Town of East Hampton born?',
#  '5a8ff6635542995651fb5086': "Who currently has more store locations? Bearno's or Patxi's Chicago Pizza?",
#  '5ae3c0cc5542992f92d82369': 'Peter Marc Jacobson is best known as the co-creator of the popular sitcom "The Nanny", which he created and wrote with his then wife an actress born in which year ?',
#  '5a8485fa5542992a431d1a41': 'Who was the brother of the architect of Hook and Ladder No. 4 located in Albany, NY?',
#  '5ae1389655429901ffe4ae05': 'Bethpage State Parkway begins with an interchange at which Long Island-based limited access highway?',
#  '5a7b73ad5542997c3ec9718c': '1990 Film Lionheart stars this actor who is best known for what type of films?',
#  '5a7a68d25542996c55b2dd98': 'How is the namesake of The Mountbatten Institute related to Elizabeth II?',
#  '5ae2bb545542992decbdcd88': "At what frequency the magazine publishes which ranked  Aditya Puri #24th in India's 50 Most powerful people of 2017 list?",
#  '5a8f47a55542997ba9cb3219': 'Which brand of canned cooked meat by Hormel Foods Corporation is used to make a popular snack and lunch food in Hawaii?',
#  '5ab1ebff5542993be8fa9882': 'Which plant genus has a longer common name, Myrtus or Eustoma?',
#  '5a7fd7305542992e7d278dc2': 'What films were the basis for "Family Guy" and the character of Peter Griffith?',
#  '5abb8aaf5542993f40c73b1c': 'In what city did Jennifer Paige Chambers appear with the creator of the characters Jiminy Glick and Ed Grimley?',
#  '5abba584554299642a094afa': 'How many yards did the nephew of Ivory Lee Brown get during his 2004 true freshman season?',
#  '5a804510554299485f5985af': 'Belle & Sebastian: The Adventure Continues is the sequel to the 2013 film "Belle and Sebastian", a French adventure film directed by who?',
#  '5abb11c15542992ccd8e7ef8': "Selena Quintanilla-Pérez's assistant and head of her fan club will be eligible for parole on what date?",
#  '5ae376a35542990afbd1e163': 'Are Peter Balakian and James Der Derian both teachers?',
#  '5adc5b875542996e68525328': 'In which St. Louis Cardinal season did a player born in 1972 blow ten saves before undergoing season-ending hip surgery?',
#  '5ae6b6065542991bbc976168': 'Out of the actors who have played the role of Luc Deveraux in the Universal Soldier franchise, which actor has also starred in the movies Holby City, Doctor Strange, the Bourne Ultimatum and Zero Dark Thirty?',
#  '5a79d2fe5542994f819ef0c3': 'Who was born first, Aleksandr Ivanovsky or Arthur Lubin?',
#  '5ab38cdd5542992ade7c6de2': "Liverpool nurse Mimi Smith was the aunt and guardian of which one of the city's most famous sons?",
#  '5ae73d235542991e8301cc29': 'What production company co-owned by Kevin Loader and Rodger Michell produced My Cousin Rachel?',
#  '5a7a33205542996a35c1712f': 'Out of two American colonies that had a series of skirmishes and raids between 1701 and 1765 at the disputed border, which British proprietary colony became a royal colony on the northeast coast of North America?',
#  '5a799dfb5542994bb9457029': 'Former race car driver Jeff Wood made his CART debut at which 1983 Nissan/Datsun-sponsored race?',
#  '5a71095e5542994082a3e4f3': "What is the name of Bruce Willis's character in Unbreakable?",
#  '5aba77be55429955dce3ee44': 'How many degrees and minutes south of the equator are the bone fragments of the extinct Ascension night heron found?',
#  '5a8af94455429971feec45b6': 'Jon S. Cardin is the nephew of a senator who has been in office since when ?',
#  '5abcedb355429959677d6b4f': 'Chris Jones is a semi-professional footballer, who played with what goalkeeper for Derby County when he was with Yorkshire?',
#  '5a713dcb5542994082a3e6d9': 'What pursuit did both Gevork Minaskanian and George Stambolian have in common?',
#  '5ae383e15542992f92d822fb': 'Which film is newer, The Apple Dumpling Gang or Heavyweights?',
#  '5a85df525542994c784ddb9f': 'What former president of ABC television is a high ranking officer in the same company as Christine Mccarthy?',
#  '5a9030ef5542995651fb50e4': 'Show Her is a song written by a country music artist who is also a former player of what sport?',
#  '5a8a2d2155429930ff3c0cdc': 'House of Many Ways is a young adult fantasy novel set in the same world as a novel that was adapted as an animated film of the same name and nominated for what?',
#  '5a88fa9e5542993b751ca8de': 'What NFL team did the 2017 ESPN College Football Friday Primetime host who played at Oklahoma in college play for?',
#  '5ae7882b554299540e5a55dd': 'What relationship does Fred Gehrke have to the 23rd overall pick in the 2010 Major League Baseball Draft?',
#  '5a81dacc55429926c1cdada0': 'Who is the author of the play that was adapted into a film and featured the orchestral arrangement Suite from Henry V?',
#  '5ab322b1554299194fa93570': 'Which type of character is featured by the P.L. Travers\'s third book and last novel in the "Mary Poppins" series?',
#  '5a8a764555429930ff3c0de1': "What distinction about his birth makes the contemporary of Bill Pollack unique as a winner of the Formula One World Drivers' Championship?",
#  '5a8d93bf554299068b959d46': 'Are both Yangzhou and Jiangyan District considered coastal cities?',
#  '5abf04ae5542993fe9a41dbf': 'What musical action does Ndebele music and Musical bow have in common?',
#  ...}

# %%
corpus['2816539']
# Out:
# {'text': 'Scott Derrickson (born July 16, 1966) is an American director, screenwriter and producer. He lives in Los Angeles, California. He is best known for directing horror films such as "Sinister", "The Exorcism of Emily Rose", and "Deliver Us From Evil", as well as the 2016 Marvel Cinematic Universe installment, "Doctor Strange."',
#  'title': 'Scott Derrickson'}

# %%
qrels
# Out:
# {'5a8b57f25542995d1e6f1371': {'2816539': 1, '10520': 1},
#  '5a8c7595554299585d9e36b6': {'33022480': 1, '804602': 1},
#  '5a85ea095542994775f606a8': {'12342237': 1, '18974107': 1},
#  '5adbf0a255429947ff17385a': {'9421721': 1, '20395866': 1},
#  '5a8e3ea95542995a26add48d': {'41146297': 1, '5382358': 1},
#  '5abd94525542992ac4f382d2': {'43665973': 1, '40901645': 1},
#  '5a85b2d95542997b5ce40028': {'507437': 1, '282635': 1},
#  '5a87ab905542996e4f3088c1': {'1922186': 1, '1922204': 1},
#  '5a7bbb64554299042af8f7cc': {'39354179': 1, '1316127': 1},
